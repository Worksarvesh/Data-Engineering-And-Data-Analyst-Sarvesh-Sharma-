# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mymoviedb.csv",lineterminator='\n')
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9827 entries, 0 to 9826
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   object
#  1   Title              9827 non-null   object
#  2   Overview           9827 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   int64
#  5   Vote_Average       9827 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9827 non-null   object
#  8   Poster_Url         9827 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 691.1+ KB

# %%
df.shape
# Out:
# (9827, 9)

# %%
df.columns
# Out:
# Index(['Release_Date', 'Title', 'Overview', 'Popularity', 'Vote_Count',
#        'Vote_Average', 'Original_Language', 'Genre', 'Poster_Url'],
#       dtype='object')

# %%
df['Genre'].head()
# Out:
# 0    Action, Adventure, Science Fiction
# 1              Crime, Mystery, Thriller
# 2                              Thriller
# 3    Animation, Comedy, Family, Fantasy
# 4      Action, Adventure, Thriller, War
# Name: Genre, dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9827.000000   9827.000000   9827.000000
# mean     40.326088   1392.805536      6.439534
# std     108.873998   2611.206907      1.129759
# min      13.354000      0.000000      0.000000
# 25%      16.128500    146.000000      5.900000
# 50%      21.199000    444.000000      6.500000
# 75%      35.191500   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %%
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
name =df['Popularity'].idxmin()
print(df.loc[name,'Title'])
# Out:
# The United States vs. Billie Holiday

# %%
# Exploration Summary


# we have a dataframe consisting of 9827 rows and 9 columns.

# our dataset looks a bit tidy with no NaNs nor duplicated values.

# Release_Date column needs to be casted into date time and to extract only the year value.

# Overview, Original_Languege and Poster-Url wouldn't be so useful during analysis, so we'll drop them.


# there is noticable outliers in Popularity column

# Vote_Average bettter be categorised for proper analysis.

# Genre column

# has comma saperated values and white spaces that needs to be handled and casted into category. Exploration Summary

# %% [markdown]
# Release Data convert to date data types and generate into only year

# %%
df['Release_Date'] = pd.to_datetime(df['Release_Date'])
print(df['Release_Date'].head())
# Out:
# 0   2021-12-15
# 1   2022-03-01
# 2   2022-02-25
# 3   2021-11-24
# 4   2021-12-22
# Name: Release_Date, dtype: datetime64[ns]

# %%
df['Release_Date'] = df['Release_Date'].dt.year
print(df['Release_Date'].head())
# Out:
# 0    2021
# 1    2022
# 2    2022
# 3    2021
# 4    2021
# Name: Release_Date, dtype: int32

# %% [markdown]
# Dropping The columns

# %%
col=['Overview', 'Original_Language', 'Poster_Url']

# %%
df.drop(col, axis=1, inplace=True, errors='ignore')

df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2022               The Batman    3827.658        1151
# 2          2022                  No Exit    2618.087         122
# 3          2021                  Encanto    2402.201        5076
# 4          2021           The King's Man    1895.511        1793
#
#    Vote_Average                               Genre
# 0           8.3  Action, Adventure, Science Fiction
# 1           8.1            Crime, Mystery, Thriller
# 2           6.3                            Thriller
# 3           7.7  Animation, Comedy, Family, Fantasy
# 4           7.0    Action, Adventure, Thriller, War

# %% [markdown]
# Categrorizing Vote_Avg column

# %%
def categorize_col(df, col, labels):
    edges = [
        df[col].min(),
        df[col].quantile(0.25),
        df[col].quantile(0.50),
        df[col].quantile(0.75),
        df[col].max()
    ]
    
    new_col = col + "_Category"
    
    df[new_col] = pd.cut(
        df[col],
        bins=edges,
        labels=labels,
        include_lowest=True
    )

# %%
labels = ['Not_popular', 'below_avg', 'average', 'popular']

categorize_col(df, 'Vote_Average', labels)

df[['Vote_Average', 'Vote_Average_Category']].head()
# Out:
#    Vote_Average Vote_Average_Category
# 0           8.3               popular
# 1           8.1               popular
# 2           6.3             below_avg
# 3           7.7               popular
# 4           7.0               average

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2022               The Batman    3827.658        1151
# 2          2022                  No Exit    2618.087         122
# 3          2021                  Encanto    2402.201        5076
# 4          2021           The King's Man    1895.511        1793
#
#    Vote_Average                               Genre Vote_Average_Category
# 0           8.3  Action, Adventure, Science Fiction               popular
# 1           8.1            Crime, Mystery, Thriller               popular
# 2           6.3                            Thriller             below_avg
# 3           7.7  Animation, Comedy, Family, Fantasy               popular
# 4           7.0    Action, Adventure, Thriller, War               average

# %%
# count number of movie are popular and avg and below avg and unpopular 
df['Vote_Average_Category'].value_counts()
# Out:
# Vote_Average_Category
# Not_popular    2567
# popular        2450
# average        2412
# below_avg      2398
# Name: count, dtype: int64

# %%
df.dropna(inplace = True)
df.isna().sum()
# Out:
# Release_Date             0
# Title                    0
# Popularity               0
# Vote_Count               0
# Vote_Average             0
# Genre                    0
# Vote_Average_Category    0
# dtype: int64

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2022               The Batman    3827.658        1151
# 2          2022                  No Exit    2618.087         122
# 3          2021                  Encanto    2402.201        5076
# 4          2021           The King's Man    1895.511        1793
#
#    Vote_Average                               Genre Vote_Average_Category
# 0           8.3  Action, Adventure, Science Fiction               popular
# 1           8.1            Crime, Mystery, Thriller               popular
# 2           6.3                            Thriller             below_avg
# 3           7.7  Animation, Comedy, Family, Fantasy               popular
# 4           7.0    Action, Adventure, Thriller, War               average

# %% [markdown]
# we will spilit geners into list and then explode out dataframe to have only one genre per row for each movie

# %%
df['Genre'] = df['Genre'].str.split(", ")
df = df.explode('Genre').reset_index(drop=True)
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2021  Spider-Man: No Way Home    5083.954        8940
# 2          2021  Spider-Man: No Way Home    5083.954        8940
# 3          2022               The Batman    3827.658        1151
# 4          2022               The Batman    3827.658        1151
#
#    Vote_Average            Genre Vote_Average_Category
# 0           8.3           Action               popular
# 1           8.3        Adventure               popular
# 2           8.3  Science Fiction               popular
# 3           8.1            Crime               popular
# 4           8.1          Mystery               popular

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25793 entries, 0 to 25792
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Release_Date           25793 non-null  int32
#  1   Title                  25793 non-null  object
#  2   Popularity             25793 non-null  float64
#  3   Vote_Count             25793 non-null  int64
#  4   Vote_Average           25793 non-null  float64
#  5   Genre                  25793 non-null  object
#  6   Vote_Average_Category  25793 non-null  category
# dtypes: category(1), float64(2), int32(1), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
df.nunique()
# Out:
# Release_Date              102
# Title                    9513
# Popularity               8160
# Vote_Count               3266
# Vote_Average               74
# Genre                      19
# Vote_Average_Category       4
# dtype: int64

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2021  Spider-Man: No Way Home    5083.954        8940
# 2          2021  Spider-Man: No Way Home    5083.954        8940
# 3          2022               The Batman    3827.658        1151
# 4          2022               The Batman    3827.658        1151
#
#    Vote_Average            Genre Vote_Average_Category
# 0           8.3           Action               popular
# 1           8.3        Adventure               popular
# 2           8.3  Science Fiction               popular
# 3           8.1            Crime               popular
# 4           8.1          Mystery               popular

# %% [markdown]
# # DATA VISUALIZATION

# %%
sns.set_style('whitegrid')

# %% [markdown]
# # What is the most frequent genre of movies on Netflix?

# %%
df['Genre'].describe()
# Out:
# count     25793
# unique       19
# top       Drama
# freq       3744
# Name: Genre, dtype: object

# %%
sns.catplot(y='Genre',data = df , kind = 'count',
           order = df['Genre'].value_counts().index,color ='#4287f5')
plt.title("Genre Column Distribution")
plt.show()

# %% [markdown]
# # Which movie has the highest vote average?

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2021  Spider-Man: No Way Home    5083.954        8940
# 2          2021  Spider-Man: No Way Home    5083.954        8940
# 3          2022               The Batman    3827.658        1151
# 4          2022               The Batman    3827.658        1151
#
#    Vote_Average            Genre Vote_Average_Category
# 0           8.3           Action               popular
# 1           8.3        Adventure               popular
# 2           8.3  Science Fiction               popular
# 3           8.1            Crime               popular
# 4           8.1          Mystery               popular

# %%
sns.catplot(y='Vote_Average_Category',data = df , kind = 'count',
           order = df['Vote_Average_Category'].value_counts().index,color ='#4287f5')
plt.title("Vote_Average Column Distribution")
plt.show()

# %% [markdown]
# #  Which movie has the highest popularity and what is its genre?

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2021  Spider-Man: No Way Home    5083.954        8940
# 2          2021  Spider-Man: No Way Home    5083.954        8940
# 3          2022               The Batman    3827.658        1151
# 4          2022               The Batman    3827.658        1151
#
#    Vote_Average            Genre Vote_Average_Category
# 0           8.3           Action               popular
# 1           8.3        Adventure               popular
# 2           8.3  Science Fiction               popular
# 3           8.1            Crime               popular
# 4           8.1          Mystery               popular

# %%
df[df['Popularity'] == df['Popularity'].max()]
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2021  Spider-Man: No Way Home    5083.954        8940
# 2          2021  Spider-Man: No Way Home    5083.954        8940
#
#    Vote_Average            Genre Vote_Average_Category
# 0           8.3           Action               popular
# 1           8.3        Adventure               popular
# 2           8.3  Science Fiction               popular

# %% [markdown]
# # Which movie has the lowest popularity?

# %%
df[df['Popularity'] == df['Popularity'].min()]
# Out:
#        Release_Date                                 Title  Popularity  \
# 25787          2021  The United States vs. Billie Holiday      13.354
# 25788          2021  The United States vs. Billie Holiday      13.354
# 25789          2021  The United States vs. Billie Holiday      13.354
# 25790          1984                               Threads      13.354
# 25791          1984                               Threads      13.354
# 25792          1984                               Threads      13.354
#
#        Vote_Count  Vote_Average            Genre Vote_Average_Category
# 25787         152           6.7            Music               average
# 25788         152           6.7            Drama               average
# 25789         152           6.7          History               average
# 25790         186           7.8              War               popular
# 25791         186           7.8            Drama               popular
# ...

# %% [markdown]
# # Q1. Which year has the most filmed movies?**

# %%
df['Release_Date'].hist()
plt.show()

# %% [markdown]
# <!-- ## 📊 Netflix Movie Data Analysis – Q&A Summary
# Q1. Which year has the most filmed movies?
#
# Answer: Recent years (around 2020–2022) have the highest number of movie releases, showing a strong increase in production in modern times.
#
# Q2. Which movie has the highest popularity and what is its genre?
#
# Answer: Spider-Man: No Way Home has the highest popularity and belongs to Action, Adventure, and Science Fiction genres.
#
# Q3. Which movie has the lowest popularity?
#
# Answer: Movies like The United States vs. Billie Holiday and Threads have the lowest popularity, mostly belonging to Drama, History, and War genres.
#
# Q4. Which movie has the highest vote average?
#
# Answer: Movies categorized as “popular” have the highest vote averages, with titles like Spider-Man: No Way Home and The Batman leading.
#
# Q5. How are movies distributed by vote average category?
#
# Answer: Movies are fairly evenly distributed across Not_popular, below_avg, average, and popular, with most falling between average and popular.
#
# Q6. What is the most frequent genre of movies on Netflix?
#
# Answer: Drama is the most frequent genre, followed by Comedy, Action, and Thriller.
#
# Q7. Why is exploding the Genre column important?
#
# Answer: Exploding the genre column allows each movie to be counted correctly across multiple genres, making genre-wise analysis accurate.
#
# Q8. Does higher popularity always mean higher rating?
#
# Answer: No, some movies have high popularity but average ratings, while some highly rated movies have low popularity.
#
# Q9. What key trend is observed in movie production over time?
#
# Answer: Movie production has increased significantly in recent years, indicating rapid content growth on streaming platforms.
#
# Q10. What is the main insight from this analysis?
#
# Answer: Netflix content is dominated by Drama and Action genres, recent releases are more frequent, and popularity does not always correlate with rating quality. -->

# %% [markdown]
# # Which year has the most filmed movies?
# ## Recent years (around 2020–2022) have the highest number of movie releases.
#
# # Which movie has the highest popularity and what is its genre?
# ## Spider-Man: No Way Home is the most popular movie and belongs to Action, Adventure, and Science Fiction genres.
#
# # Which movie has the lowest popularity?
# ## The United States vs. Billie Holiday and Threads have the lowest popularity and mainly belong to Drama, History, and War genres.
#
# # Which movie has the highest vote average?
# ## Movies categorized as popular have the highest vote averages.
#
# # How are movies distributed by vote average category?
# ## Movies are fairly evenly distributed across Not_popular, below_avg, average, and popular categories.
#
# # What is the most frequent genre of movies?
# ## Drama is the most frequent genre, followed by Comedy, Action, and Thriller.
